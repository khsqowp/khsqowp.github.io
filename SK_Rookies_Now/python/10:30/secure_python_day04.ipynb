# %% [markdown]
# #### 함수(function - oop method)
# - 코드 재사용
# - 가독성 향상
# - 유지보수 용이
# - 디버깅 용이
# - 모듈화 (import utils)

# %% [markdown]
# <code>
# def 함수명([매개변수, 매개변수, .....]) :
#     실행할 코드
#     return 결과값(내장변수타입) # 반환이 필요없다면 생략 가능
# </code>

# %%
print('working - ')
print('default parameter - ')
def greet(name='guest') :
    '''사용자에게 인사하는 함수'''
    return f'hi ~, {name}'
# Out:
# working -
# default parameter -

# %%
print('caller - ')
result = greet('jslim')
print(result)
# Out:
# caller -
# hi ~, jslim

# %%
def userAdd(a, b) :
    return a ** b

# %%
print('positional argument - ')
result = userAdd(3, 2)
print('type   - ' , type(result))
print('result - ' , result)
# Out:
# positional argument -
# type   -  <class 'int'>
# result -  9

# %%
print('keyword argument - ')
result = userAdd(b=3, a=2)
print('type   - ' , type(result))
print('result - ' , result)
# Out:
# keyword argument -
# type   -  <class 'int'>
# result -  8

# %% [markdown]
# - 람다 함수(Lambda function) == 익명의 함수(anonymous)
# - lambda 매개변수 : 실행문 (return 키워드 없이 결과값을 바로 반환)
# - map, filter ~

# %%
add = lambda x, y : x + y
print('type - ' , type(add))
# Out:
# type -  <class 'function'>

# %%
result = add(3,5)
print('result - ' , result )
# Out:
# result -  8

# %%
lst = [1,2,3,4,5,6,7,8] 

print('case01 - ')
result = [ data ** 2 for data in lst]
print(result)

print()

print('case02 - ') 
print('map - 열거형 타입(반복 가능한 요소에 대해서 특정 함수를 적용하고 그 결과를 map 객체로 반환')
print('map(function, iterable)') 
double = list(map(lambda data : data ** 2 , lst))
print(double)

print()
print('case03 - ') 
print('filter(function, iterable) ')
even = list(filter(lambda data : data%2 == 0 , lst))
print(even)
# Out:
# case01 -
# [1, 4, 9, 16, 25, 36, 49, 64]
#
# case02 -
# map - 열거형 타입(반복 가능한 요소에 대해서 특정 함수를 적용하고 그 결과를 map 객체로 반환
# map(function, iterable)
# [1, 4, 9, 16, 25, 36, 49, 64]
#
# case03 -
# filter(function, iterable)
# [2, 4, 6, 8]

# %%
wordLst = ['pineApple', 'chry', 'watermelon', 'banana' , 'apple'] 
result  = sorted(wordLst , key= lambda x : len(x) ) 
print(result)
# Out:
# ['chry', 'apple', 'banana', 'pineApple', 'watermelon']

# %%
# 반환예시) [ 'www.skshieldus.com' , 'www.samsung.com' , etc.... ] 
def makeUrl(lst : list) -> list :
    return list(map(lambda x:'www.'+x+'.com', lst))

# %%
companyLst = ['skshieldus', 'samsung', 'lgcns', 'skcnc', '<script>alert(1)</script>'] 
urls = makeUrl(companyLst)
print(urls)
# Out:
# ['www.skshieldus.com', 'www.samsung.com', 'www.lgcns.com', 'www.skcnc.com', 'www.<script>alert(1)</script>.com']

# %%
# 코드의 개선점 
# 내부값이 문자열인지, 악성문자열 검증 
# 웹 페이지에 출력하면 XSS 취약점 발생 
# quote() : 공백, 특수문자 등을 안전하게 인코딩 

from urllib.parse import quote

# def safeMakeUrl(lst : list) -> list :
#     return list(map(lambda x:'www.'+quote(x)+'.com', lst))

def safeMakeUrl(lst : list ) -> list :
    
    if not isinstance(lst, list) : 
        raise TypeError("입력은 리스트 타입으로 전달 부탁드립니다.") 
    if not all(isinstance(name, str) for name in lst) :
        raise ValueError('요소의 타입은 문자열')

    # 안전하게 URL 인코딩
    return list(map(lambda x:'www.'+quote(x)+'.com', lst))

# %%
companyLst = ['skshieldus', 'samsung', 'lgcns', 'skcnc', '<script>alert(1)</script>'] 
urls = safeMakeUrl(companyLst)
print(urls)
# Out:
# ['www.skshieldus.com', 'www.samsung.com', 'www.lgcns.com', 'www.skcnc.com', 'www.%3Cscript%3Ealert%281%29%3C/script%3E.com']

# %%
def myColor(name, color, isFlag : bool) :
     print(f"{name}님은 {color}색을 {'좋아' if isFlag==True else '싫어'}합니다.")

# %%
# 출력예시) xxxx님은 xxx 색을 좋아(싫어)합니다.
myColor('섭섭님', 'red' , False)
myColor('섭섭님', 'blue' , True)
# Out:
# 섭섭님님은 red색을 싫어합니다.
# 섭섭님님은 blue색을 좋아합니다.

# %% [markdown]
# - 변수의 스코프에 대한 이해(LEGB)

# %%
# 전역변수 
globalVar = 10 

def outer() :
    # 외부 함수 변수
    enclosingVar = 20
    
    def inner() :
        # 지역변수 
        localVar = 30
        print('global - ' , globalVar) 
        print('enclosingVar - ' , enclosingVar)
        print('localVar - ' , localVar)
    inner()
    # error
    # print(localVar)

# %%
outer()
print('globalVar - ' , globalVar)
# error
# print(enclosingVar)
# Out:
# global -  10
# enclosingVar -  20
# localVar -  30
# globalVar -  10

# %%
x = 10 
def test() :
    x = 20

# %%
test()
print('x - ' , x )
# Out:
# x -  10

# %%
cnt = 0 

def increment() :
    global cnt 
    cnt += 1

# %%
increment()
increment()
increment()
print('cnt - ' , cnt )
# Out:
# cnt -  3

# %%
def outer() :
    outerVar = 10 
    def inner() :
        nonlocal outerVar
        outerVar += 1
        print('inner outerVar : ' , outerVar)
    inner()
    print('outer outerVar : ' , outerVar)

# %%
outer()
# Out:
# inner outerVar :  11
# outer outerVar :  11

# %% [markdown]
# - 클로저(Closure)(중첩함수 - 함수내부에서 외부함수의 변수를 기억
# - 함수가 종료되어도 외부 변수를 기억하는 것이 핵심
# - 상태유지(전역변수를 쓰지 않고도 함수 내부에서 상태 유지 가능)
# - 함수 장식자(데코레이터) : 클로저기반

# %%
def outer(name : str) :
    def inner() :
        return f'hi ~ , {name}'
    return inner # 함수반환

# %%
msg = outer('jslim')
print('type - ' , type(msg))
print('result - ' , msg() )
# Out:
# type -  <class 'function'>
# result -  hi ~ , jslim

# %%
# 전역변수를 사용하지 않고 상태를 유지하는 코드 개선

def counter() :
    count = 0 
    def increase() : 
        nonlocal count 
        count += 1     
        return count
    return increase

# %%
cnt = counter()
print(cnt())
print(cnt())
print(cnt())
print(cnt())
print(cnt())
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# - decorator(함수 장식자)
# - 함수를 감싸서 기능(공통의 로직)을 추가시켜주는 것
# - 현업에서 자주 사용되는데 : 로깅, 권한체크, 실행시간 측정 etc.....

# %%
def commonChecking() :
    print('>>>>>>> permission check')
def commonLogging() :
    print('>>>>>>> log..... ')
    
def decorator(checkingFunc, logginFunc) :
    def logic() :
        checkingFunc()
        print('업무로직')
        logginFunc()
    return logic

# %%
# c = commonChecking()
# l = commonLogging()
innerLogic = decorator(commonChecking, commonLogging)
innerLogic()
# Out:
# >>>>>>> permission check
# 업무로직
# >>>>>>> log.....

# %%
def clo(num):
    def test():
        x = 10
        return x + num
    return test
a = clo(1)
print(a())
print(a())
print(a())
print(a())
# Out:
# 11
# 11
# 11
# 11

# %%
def clo(num):
    x = 10
    def test():
        nonlocal x
        x = x + num
        return x
    return test
    
a = clo(1)
print(a())
print(a())
print(a())
print(a())
# Out:
# 11
# 12
# 13
# 14

# %%
print('실행시간 성능 로그 - ') 
from time import time 

def timer() :
    def wrapper():
        pass

def timerFunc() : 
    pass
# Out:
# 실행시간 성능 로그 -

# %%
inner = timer(timerFunc)
inner()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[182], line 1
# ----> 1 inner = timer(timerFunc)
#       2 inner()
#
# TypeError: timer() takes 0 positional arguments but 1 was given

# %% [markdown]
# - 가변인자 함수 : 몆개의 매개변수가 전달될지 모르는 것
# - *args : tuple
# - **args : 키워드 인자로 dict

# %%
def variableLenArgs(*args : int ) -> None :
    print('type - ' , type(args)) 
    total = sum(args)
    return total

# %%
result = variableLenArgs(1,2,3)
print(result)
result = variableLenArgs(1,2,3,4,5)
print(result)
result = variableLenArgs(1,2,3,4,5,6,7,8)
print(result)
# Out:
# type -  <class 'tuple'>
# 6
# type -  <class 'tuple'>
# 15
# type -  <class 'tuple'>
# 36

# %%
def variableLenArgsDict(**args) :
    print('type - ' , type(args)) 
    for key, value in args.items() : 
        print(key , value)

# %%
variableLenArgsDict(name='jslim', age=30, region='seoul')
# Out:
# type -  <class 'dict'>
# name jslim
# age 30
# region seoul

# %%
def variableLenArgsMix(subject, *args,  **kwargs) : 
    print('subject  - ' , subject)
    print('args     - ' , args)
    print('kwargs   - ' , kwargs)

# %%
variableLenArgsMix("사용자 정보", "임섭순", "섭섭해", "쉴더스" ,  a=1, b=2)
# Out:
# subject  -  사용자 정보
# args     -  ('임섭순', '섭섭해', '쉴더스')
# kwargs   -  {'a': 1, 'b': 2}

# %%
# endpoint
# Quiz
# 아래와 같은 api 요청을 생성
# https://api.v1.example.com/search?q=secure&page=2 
def makeApiRequest(endpoint, **params) :
    queryString = urlencode(params)
    return endpoint+'?'+queryString

# %%
api = makeApiRequest('https://api.v1.example.com/search' , q='secure' , page=2)
print(api)
# Out:
# https://api.v1.example.com/search?q=secure&page=2

# %%
from urllib.parse import urlencode
params = {"q" : 'secure' , "page" : 2} 
queryString = urlencode(params)
print('https://api.v1.example.com/search?'+queryString)
# Out:
# https://api.v1.example.com/search?q=secure&page=2

# %%
print('보안 - 코드 개션')
from urllib.parse import urlencode
def makeApiRequest(endpoint, **params) :
    
    whiteLst = {'q', 'page', 'lang'}
    safeParams = { k : v for k, v in params.items() if k in whiteLst }
    queryString = urlencode(safeParams)
    return endpoint+'?'+queryString
# Out:
# 보안 - 코드 개션

# %%
api = makeApiRequest('https://api.v1.example.com/search' , q='secure' , page=2 , token='shieldus')
print(api)
# Out:
# https://api.v1.example.com/search?q=secure&page=2
